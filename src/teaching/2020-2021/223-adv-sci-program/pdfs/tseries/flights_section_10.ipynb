# %% [markdown]
# * Author: Patrick Earl
# * Course: CSC223
# * Creation Date: 4/23/2021
#
# Example of Data Analysis in Python using NYCFlights13 Dataset
#
# Section 10

# %% [markdown]
# ## Introduction
#
# This will be analyzing the nycflights13 dataset
#
# Source: <https://github.com/tidyverse/nycflights13>

# %% [markdown]
# ## Data Prep
#
# This is where import statements and importing the datasets is, no analysis here

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdate

# %%
dtypes = {
    'year': str,
    'month': str,
    'day': str,
    'hour': str,
    'minute': str
}

flights = pd.read_csv('./flight_data/nyc_flights.csv', dtype=dtypes)

flights.head()
# Out:
#    year month day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013     1   1     517.0             515        2.0     830.0
# 1  2013     1   1     533.0             529        4.0     850.0
# 2  2013     1   1     542.0             540        2.0     923.0
# 3  2013     1   1     544.0             545       -1.0    1004.0
# 4  2013     1   1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 2             850       33.0      AA    1141  N619AA    JFK  MIA     160.0
# 3            1022      -18.0      B6     725  N804JB    JFK  BQN     183.0
# 4             837      -25.0      DL     461  N668DN    LGA  ATL     116.0
#
#    distance hour minute             time_hour
# 0      1400    5     15  2013-01-01T10:00:00Z
# 1      1416    5     29  2013-01-01T10:00:00Z
# 2      1089    5     40  2013-01-01T10:00:00Z
# 3      1576    5     45  2013-01-01T10:00:00Z
# 4       762    6      0  2013-01-01T11:00:00Z

# %%
weather = pd.read_csv('./flight_data/nyc_weather.csv')
weather.head()
# Out:
#   origin  year  month  day  hour   temp   dewp  humid  wind_dir  wind_speed  \
# 0    EWR  2013      1    1     1  39.02  26.06  59.37     270.0    10.35702
# 1    EWR  2013      1    1     2  39.02  26.96  61.63     250.0     8.05546
# 2    EWR  2013      1    1     3  39.02  28.04  64.43     240.0    11.50780
# 3    EWR  2013      1    1     4  39.92  28.04  62.21     250.0    12.65858
# 4    EWR  2013      1    1     5  39.02  28.04  64.43     260.0    12.65858
#
#    wind_gust  precip  pressure  visib             time_hour
# 0        NaN     0.0    1012.0   10.0  2013-01-01T06:00:00Z
# 1        NaN     0.0    1012.3   10.0  2013-01-01T07:00:00Z
# 2        NaN     0.0    1012.5   10.0  2013-01-01T08:00:00Z
# 3        NaN     0.0    1012.2   10.0  2013-01-01T09:00:00Z
# 4        NaN     0.0    1011.9   10.0  2013-01-01T10:00:00Z

# %%
flights = pd.merge(flights, weather, on=['origin', 'time_hour'], suffixes=(None, '_right'))

# %% [markdown]
# ## Number of Flights leaving
#
# Plot a count of the number of flights leaving on a rolling daily count

# %%
flights['datetime'] = pd.to_datetime(flights['year'] + '/' + 
                                     flights['month'] + '/' +
                                     flights['day'] + ' ' + 
                                     flights['hour'] + ':' +
                                     flights['minute'])

flights['datetime'].head()
# Out:
# 0   2013-01-01 05:15:00
# 1   2013-01-01 05:58:00
# 2   2013-01-01 05:29:00
# 3   2013-01-01 05:40:00
# 4   2013-01-01 05:45:00
# Name: datetime, dtype: datetime64[ns]

# %%
time_index = flights.set_index('datetime')
time_index = time_index.drop(['year', 'month', 'day', 'hour', 'minute'], axis=1)

time_index.head()
# Out:
#                      dep_time  sched_dep_time  dep_delay  arr_time  \
# datetime
# 2013-01-01 05:15:00     517.0             515        2.0     830.0
# 2013-01-01 05:58:00     554.0             558       -4.0     740.0
# 2013-01-01 05:29:00     533.0             529        4.0     850.0
# 2013-01-01 05:40:00     542.0             540        2.0     923.0
# 2013-01-01 05:45:00     544.0             545       -1.0    1004.0
#
#                      sched_arr_time  arr_delay carrier  flight tailnum origin  \
# datetime
# 2013-01-01 05:15:00             819       11.0      UA    1545  N14228    EWR
# 2013-01-01 05:58:00             728       12.0      UA    1696  N39463    EWR
# 2013-01-01 05:29:00             830       20.0      UA    1714  N24211    LGA
# 2013-01-01 05:40:00             850       33.0      AA    1141  N619AA    JFK
# 2013-01-01 05:45:00            1022      -18.0      B6     725  N804JB    JFK
#
#                      ... hour_right   temp   dewp  humid  wind_dir  \
# datetime             ...
# 2013-01-01 05:15:00  ...          5  39.02  28.04  64.43     260.0
# 2013-01-01 05:58:00  ...          5  39.02  28.04  64.43     260.0
# 2013-01-01 05:29:00  ...          5  39.92  24.98  54.81     250.0
# 2013-01-01 05:40:00  ...          5  39.02  26.96  61.63     260.0
# 2013-01-01 05:45:00  ...          5  39.02  26.96  61.63     260.0
#
#                      wind_speed  wind_gust  precip  pressure  visib
# datetime
# 2013-01-01 05:15:00    12.65858        NaN     0.0    1011.9   10.0
# 2013-01-01 05:58:00    12.65858        NaN     0.0    1011.9   10.0
# 2013-01-01 05:29:00    14.96014   21.86482     0.0    1011.4   10.0
# 2013-01-01 05:40:00    14.96014        NaN     0.0    1012.1   10.0
# 2013-01-01 05:45:00    14.96014        NaN     0.0    1012.1   10.0
#
# [5 rows x 27 columns]

# %%
daily = time_index['dep_time'].resample('D').count()

daily.plot()
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
feb = time_index.loc['2013-02'][['dep_delay', 'temp', 'precip', 'wind_speed']].resample('D').agg({
    'dep_delay': 'count',
    'temp': 'mean',
    'precip': 'sum',
    'wind_speed': 'mean'
})

ax = feb.plot(kind='bar', subplots=True, layout=(4,1), legend=False, figsize=(15, 15))
ax[0,0].set_title('Number of Flights in Feb-2013');
# Set the ticklabel based on the DatetimeIndex. Use the "strftime" function on each Index and rotate by 45 degrees
# Bar charts axises start at 0, so mdates sees .
ax[3,0].set_xticklabels([x.strftime('%m/%d') for x in feb.index], rotation=45);
